# %% [markdown]
# # Netflix EDA — Exploration Notebook
#
# This notebook is for **development experimentation only**.
# The final report is in `report/report.qmd`.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from netflix_analysis.data import NetflixDataLoader, NetflixDataCleaner
from netflix_analysis.analysis import NetflixExplorer

# %matplotlib inline
sns.set_theme(style='darkgrid')

# %%
loader = NetflixDataLoader('../data/netflix_titles.csv')
raw_df = loader.load()
raw_df.head()

# %%
cleaner = NetflixDataCleaner(raw_df)
clean_df = cleaner.clean()
clean_df.info()

# %%
explorer = NetflixExplorer(clean_df)

# Quick look at distributions
print(explorer.content_type_distribution())
print()
print(explorer.top_countries())
